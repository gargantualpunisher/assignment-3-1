# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.chrome.service import Service

# %%
drivers = webdriver.Chrome(r"C:\Users\Dell\Videos\chromedriver_win32\chromedriver.exe")

drivers.get('https://www.youtube.com/watch?v=WOdnRhWeHoY')

# %%
# who commented
Time = []
time = drivers.find_elements(By.XPATH, '//*[@id="header-author"]/yt-formatted-string/a')

for i in time[0:500]:
    Time.append(i.text)
len(Time)
# Out:
# 500

# %%
comments = drivers.find_elements(By.XPATH, '//*[@id="content-text"]')

Comments =[]

for i in comments[0:500]:
    Comments.append(i.text)
len(Comments)
# Out:
# 500

# %%
import pandas as pd
final =pd.DataFrame()
final['Time']= Time
final['Comments']= Comments

final.head(50)
# Out:
#                      Time                                           Comments
# 0             2 years ago  Hanjee Hanjee Fam ! Jeh Vadiya lageya Bai\nCom...
# 1            5 months ago  If Legend Moosewale record this in his voice i...
# 2             2 weeks ago  People saying that if sidhu has recorded this ...
# 3             1 month ago  Nodoubt Punjabi Singers are Had a Separate Fan...
# 4             7 hours ago                             80's beat never fades
# 5             10 days ago  I am from Karnataka I don't know this lyrix bu...
# 6              4 days ago  One legend died and two born. Shubh & Chani. T...
# 7             2 weeks ago  No doubt Punjabi singers had a separate FANBAS...
# 8    2 weeks ago (edited)  No doubt Punjabi singers had a separate FANBAS...
# 9             1 month ago           Legend never be die    siddhu moosewala
# 10            2 weeks ago       His vibes can be felt from his writings also
# ...
